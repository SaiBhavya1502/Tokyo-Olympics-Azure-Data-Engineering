# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.sql.types import *

# %%
athletes = spark.read.format("csv") \
.option("header","true") \
.option("inferSchema","true") \
.load("/Volumes/main/tokyo/tokyo_files/athletes.csv")

coaches = spark.read.format("csv") \
.option("header","true") \
.option("inferSchema","true") \
.load("/Volumes/main/tokyo/tokyo_files/coaches.csv")

entriesgender = spark.read.format("csv") \
.option("header","true") \
.option("inferSchema","true") \
.load("/Volumes/main/tokyo/tokyo_files/entriesgender.csv")

medals = spark.read.format("csv") \
.option("header","true") \
.option("inferSchema","true") \
.load("/Volumes/main/tokyo/tokyo_files/medals.csv")

teams = spark.read.format("csv") \
.option("header","true") \
.option("inferSchema","true") \
.load("/Volumes/main/tokyo/tokyo_files/teams.csv")

# %%
display(athletes)

# %%
spark.sql("SHOW CATALOGS").show(truncate=False)

# %%
spark.sql("SHOW SCHEMAS IN tokyo_olympicdb").show(truncate=False)

# %%
spark.sql("SHOW VOLUMES IN tokyo_olympicdb.tokyo").show(truncate=False)

# %%
athletes = spark.read.format("csv") \
.option("header", "true") \
.option("inferSchema", "true") \
.load("/Volumes/tokyo_olympicdb/tokyo/tokyo_files/athletes.csv")

coaches = spark.read.format("csv") \
.option("header", "true") \
.option("inferSchema", "true") \
.load("/Volumes/tokyo_olympicdb/tokyo/tokyo_files/coaches.csv")

entriesgender = spark.read.format("csv") \
.option("header", "true") \
.option("inferSchema", "true") \
.load("/Volumes/tokyo_olympicdb/tokyo/tokyo_files/entriesgender.csv")

medals = spark.read.format("csv") \
.option("header", "true") \
.option("inferSchema", "true") \
.load("/Volumes/tokyo_olympicdb/tokyo/tokyo_files/medals.csv")

teams = spark.read.format("csv") \
.option("header", "true") \
.option("inferSchema", "true") \
.load("/Volumes/tokyo_olympicdb/tokyo/tokyo_files/teams.csv")

# %%
spark.sql("SHOW VOLUMES IN tokyo_olympicdb.tokyo").show(truncate=False)

# %%
display(dbutils.fs.ls("/Volumes/tokyo_olympicdb/tokyo/tokyo_files"))

# %%
spark.sql("LIST '/Volumes/tokyo_olympicdb/tokyo/tokyo_files'").show(truncate=False)
