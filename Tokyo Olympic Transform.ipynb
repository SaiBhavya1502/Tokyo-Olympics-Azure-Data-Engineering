# %%
athletes = spark.read.format("csv") \
.option("header","true") \
.option("inferSchema","true") \
.load("/Volumes/tokyo_olympicdb/tokyo/tokyo_files/Athletes (1).csv")

coaches = spark.read.format("csv") \
.option("header","true") \
.option("inferSchema","true") \
.load("/Volumes/tokyo_olympicdb/tokyo/tokyo_files/Coaches.csv")

entriesgender = spark.read.format("csv") \
.option("header","true") \
.option("inferSchema","true") \
.load("/Volumes/tokyo_olympicdb/tokyo/tokyo_files/EntriesGender.csv")

medals = spark.read.format("csv") \
.option("header","true") \
.option("inferSchema","true") \
.load("/Volumes/tokyo_olympicdb/tokyo/tokyo_files/Medals.csv")

teams = spark.read.format("csv") \
.option("header","true") \
.option("inferSchema","true") \
.load("/Volumes/tokyo_olympicdb/tokyo/tokyo_files/Teams.csv")

# %%
for f in dbutils.fs.ls("/Volumes/tokyo_olympicdb/tokyo/tokyo_files/"):
    print(f.path)

# %%
athletes = spark.read.format("csv") \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .load("dbfs:/Volumes/tokyo_olympicdb/tokyo/tokyo_files/athletes.csv")

# %%
coaches = spark.read.format("csv") \
.option("header","true") \
.option("inferSchema","true") \
.load("dbfs:/Volumes/tokyo_olympicdb/tokyo/tokyo_files/coaches.csv")

entriesgender = spark.read.format("csv") \
.option("header","true") \
.option("inferSchema","true") \
.load("dbfs:/Volumes/tokyo_olympicdb/tokyo/tokyo_files/entriesgender.csv")

medals = spark.read.format("csv") \
.option("header","true") \
.option("inferSchema","true") \
.load("dbfs:/Volumes/tokyo_olympicdb/tokyo/tokyo_files/medals.csv")

teams = spark.read.format("csv") \
.option("header","true") \
.option("inferSchema","true") \
.load("dbfs:/Volumes/tokyo_olympicdb/tokyo/tokyo_files/teams.csv")

# %%
athletes.show()

# %%
athletes.printSchema()

# %%
coaches.show()

# %%
coaches.printSchema()

# %%
entriesgender.show()

# %%
entriesgender.printSchema()

# %%
medals.show()

# %%
medals.printSchema()

# %%
teams.show()

# %%
teams.printSchema()
